# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
data_folder = './data/'
countries = ['CA', 'DE', 'FR', 'GB', 'IN', 'JP', 'KR', 'MX', 'RU', 'US']
category_ext = '_category_id.json'
csv_ext = 'videos.csv'

# %%
countries_df = []
for country in countries:
    try:
        df = pd.read_csv(data_folder + country + csv_ext, encoding = "utf-8")
        countries_df.append(df)
    except UnicodeDecodeError:
        print(f'Cant decode {country}')
        continue

print("Data ingested")
# Out:
# Data ingested

# %%
countries_df[4]
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37347  iNHecA3PJCo      18.14.06
# 37348  dpPmPbhcslM      18.14.06
# 37349  mV6aztP58f8      18.14.06
# 37350  qxqDNP1bDEw      18.14.06
# 37351  wERgpPK44w0      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...                                                  ...                 ...
# ...

# %%
df = countries_df[4]

df['trending_date'] = pd.to_datetime(df['trending_date'], format='%y.%d.%m')
df['publish_time'] = pd.to_datetime(df['publish_time'])
df['publish_time'] = df['publish_time'].dt.tz_localize(None)
df['time_to_trend'] = (df['trending_date'] - df['publish_time']).astype('timedelta64[h]')

# df['time_to_trend'].sort_index(ascending=False)

plt.hist(df['time_to_trend'])
plt.show()
